# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 120)

# %%
# Final comparison table
comp = pd.read_csv('all_metric_comparison.csv')
comp
# Out:
#                      Metric Mol2Raman (in-dist QM9)  SpectraLoRA+ES (OOD RamanChemBL)  SpectraLoRA Raw  \
# 0         Fingerprint F1@10                   0.551                             0.418            0.321
# 1         Fingerprint F1@15                   0.631                             0.532            0.426
# 2         Fingerprint F1@20                   0.705                             0.598            0.489
# 3     Fingerprint Recall@15                   0.634                             0.703            0.438
# 4  Fingerprint Precision@15                   0.629                             0.440            0.444
# 5                Full F1@10                       —                             0.371            0.276
# 6                Full F1@15                       —                             0.472            0.366
# 7                Full F1@20                       —                             0.532            0.420
# ...

# %%
# All checkpoints trajectory
full = pd.read_csv('all_checkpoints_full.csv')
full[['checkpoint', 'fingerprint_f1@10', 'fingerprint_f1@15', 'fingerprint_f1@20', 
      'fingerprint_p@15', 'fingerprint_r@15', 'full_f1@15', 'cosine']]
# Out:
#         checkpoint  fingerprint_f1@10  fingerprint_f1@15  fingerprint_f1@20  fingerprint_p@15  fingerprint_r@15  \
# 0        raw_input           0.320775           0.425760           0.488928          0.443716          0.438262
# 1   v8/phase1_best           0.361891           0.478701           0.553372          0.427753          0.568378
# 2       v8/es_best           0.397393           0.510465           0.578235          0.425842          0.666712
# 3     v8/es_step50           0.376689           0.487891           0.560190          0.422695          0.603035
# 4    v8/es_step100           0.383322           0.490666           0.565289          0.419598          0.617408
# 5    v8/es_step150           0.385502           0.495638           0.565129          0.420653          0.630962
# 6    v8/es_step200           0.389397           0.502462           0.569760          0.422760          0.647659
# ...
