# %%
import torch
from detanet_model import nn_vib_analysis,Lorenz_broadening,DetaNet,get_raman_intensity,uv_model,nmr_calculator,nmr_sca,charge_model

# %%
device=torch.device('cpu')
dtype=torch.float32

# %%
'''
The spectrum calculation modules of DetaNet consists of a tensor of the shape [Num_atom,3] 
indicating the position of the atom and a LongTensor of [Num_atom] indicating the element type.
Here, we take the example of Phenol
'''
pos=torch.tensor([[ 9.7233e-02,  1.3689e+00,  1.3115e-01],
        [ 6.7777e-02,  3.2910e-03,  3.8910e-02],
        [ 7.6066e-02, -6.6728e-01, -1.1832e+00],
        [ 4.4743e-02, -2.0582e+00, -1.2085e+00],
        [ 5.2200e-03, -2.7850e+00, -2.4071e-02],
        [-2.7410e-03, -2.1055e+00,  1.1924e+00],
        [ 2.8234e-02, -7.1819e-01,  1.2309e+00],
        [ 1.2295e-01,  1.7542e+00, -7.5192e-01],
        [ 1.0686e-01, -1.0483e-01, -2.1109e+00],
        [ 5.1425e-02, -2.5716e+00, -2.1622e+00],
        [-1.9064e-02, -3.8668e+00, -4.6867e-02],
        [-3.3378e-02, -2.6606e+00,  2.1220e+00],
        [ 2.2412e-02, -1.7973e-01,  2.1697e+00]],device=device,dtype=dtype)

z=torch.LongTensor([8, 6, 6, 6, 6, 6, 6, 1, 1, 1, 1, 1, 1])

pos.shape,z.shape
# Out:
# (torch.Size([13, 3]), torch.Size([13]))

# %%
'''Loading model'''
charge_model_=charge_model(device=device)
vib_model=nn_vib_analysis(device=device,Linear=False,scale=0.965)
nmr_model=nmr_calculator(device=device)
uv_model_=uv_model(device=device)

charge_model_
# Out:
# DetaNet(
#   (Embedding): Embedding(
#     (act): Swish()
#     (elec_emb): Linear(in_features=16, out_features=128, bias=False)
#     (nuclare_emb): Embedding(10, 128)
#     (ls): Linear(in_features=128, out_features=128, bias=True)
#   )
#   (Radial): Radial_Basis(
#     (radial): Bessel_Function()
#   )
#   (blocks): Sequential(
#     (0): Interaction_Block(
#       (message): Message(
#         (Attention): Edge_Attention(
#           (actq): Swish()
#           (actk): Swish()
#           (actv): Swish()
#           (acta): Swish()
#           (softmax): Softmax(dim=-1)
#           (lq): Linear(in_features=128, out_features=128, bias=True)
#           (lk): Linear(in_features=128, out_features=128, bias=True)
#           (lv): Linear(in_features=128, out_features=256, bias=True)
#           (la): Linear(in_features=256, out_features=256, bias=True)
#           (lrbf): Linear(in_features=32, out_features=128, bias=False)
#           (lkrbf): Linear(in_features=128, out_features=128, bias=False)
#           (lvrbf): Linear(in_features=128, out_features=256, bias=False)
#         )
#         (tp): TensorProduct(128x0e x 1x1o+1x2e+1x3o -> 128x1o+128x2e+128x3o | 384 paths | 384 weights)
#       )
#       (update): Update(
#         (actu): Swish()
#         (drop): Dropout(p=0.0, inplace=False)
#         (outt): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#         (outs): Linear(in_features=128, out_features=128, bias=True)
#         (uattn): Tensorproduct_Attention(
#           (lq): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (lk): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (lv): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (ls): Linear(in_features=128, out_features=256, bias=True)
#           (lvs): Linear(in_features=128, out_features=128, bias=True)
#           (tp1): TensorProduct(128x1o+128x2e+128x3o x 128x1o+128x2e+128x3o -> 128x0e | 384 paths | 0 weights)
#           (tp2): TensorProduct(128x0e x 128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 384 paths | 384 weights)
#           (softmax): Softmax(dim=-1)
#           (actlvs): Swish()
#         )
#       )
#     )
#     (1): Interaction_Block(
#       (message): Message(
#         (Attention): Edge_Attention(
#           (actq): Swish()
#           (actk): Swish()
#           (actv): Swish()
#           (acta): Swish()
#           (softmax): Softmax(dim=-1)
#           (lq): Linear(in_features=128, out_features=128, bias=True)
#           (lk): Linear(in_features=128, out_features=128, bias=True)
#           (lv): Linear(in_features=128, out_features=256, bias=True)
#           (la): Linear(in_features=256, out_features=256, bias=True)
#           (lrbf): Linear(in_features=32, out_features=128, bias=False)
#           (lkrbf): Linear(in_features=128, out_features=128, bias=False)
#           (lvrbf): Linear(in_features=128, out_features=256, bias=False)
#         )
#         (tp): TensorProduct(128x0e x 1x1o+1x2e+1x3o -> 128x1o+128x2e+128x3o | 384 paths | 384 weights)
#       )
#       (update): Update(
#         (actu): Swish()
#         (drop): Dropout(p=0.0, inplace=False)
#         (outt): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#         (outs): Linear(in_features=128, out_features=128, bias=True)
#         (uattn): Tensorproduct_Attention(
#           (lq): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (lk): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (lv): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (ls): Linear(in_features=128, out_features=256, bias=True)
#           (lvs): Linear(in_features=128, out_features=128, bias=True)
#           (tp1): TensorProduct(128x1o+128x2e+128x3o x 128x1o+128x2e+128x3o -> 128x0e | 384 paths | 0 weights)
#           (tp2): TensorProduct(128x0e x 128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 384 paths | 384 weights)
#           (softmax): Softmax(dim=-1)
#           (actlvs): Swish()
#         )
#       )
#     )
#     (2): Interaction_Block(
#       (message): Message(
#         (Attention): Edge_Attention(
#           (actq): Swish()
#           (actk): Swish()
#           (actv): Swish()
#           (acta): Swish()
#           (softmax): Softmax(dim=-1)
#           (lq): Linear(in_features=128, out_features=128, bias=True)
#           (lk): Linear(in_features=128, out_features=128, bias=True)
#           (lv): Linear(in_features=128, out_features=256, bias=True)
#           (la): Linear(in_features=256, out_features=256, bias=True)
#           (lrbf): Linear(in_features=32, out_features=128, bias=False)
#           (lkrbf): Linear(in_features=128, out_features=128, bias=False)
#           (lvrbf): Linear(in_features=128, out_features=256, bias=False)
#         )
#         (tp): TensorProduct(128x0e x 1x1o+1x2e+1x3o -> 128x1o+128x2e+128x3o | 384 paths | 384 weights)
#       )
#       (update): Update(
#         (actu): Swish()
#         (drop): Dropout(p=0.0, inplace=False)
#         (outt): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#         (outs): Linear(in_features=128, out_features=128, bias=True)
#         (uattn): Tensorproduct_Attention(
#           (lq): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (lk): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (lv): Linear(128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 49152 weights)
#           (ls): Linear(in_features=128, out_features=256, bias=True)
#           (lvs): Linear(in_features=128, out_features=128, bias=True)
#           (tp1): TensorProduct(128x1o+128x2e+128x3o x 128x1o+128x2e+128x3o -> 128x0e | 384 paths | 0 weights)
#           (tp2): TensorProduct(128x0e x 128x1o+128x2e+128x3o -> 128x1o+128x2e+128x3o | 384 paths | 384 weights)
#           (softmax): Softmax(dim=-1)
#           (actlvs): Swish()
#         )
#       )
#     )
#   )
#   (sout): MLP(
#     (mlp): Sequential(
#       (0): Linear(in_features=128, out_features=128, bias=True)
#       (1): Swish()
#       (2): Dropout(p=0.0, inplace=False)
#       (3): Linear(in_features=128, out_features=1, bias=True)
#     )
#   )
# )

# %%
'''Caculation of atomic charge'''

charge=charge_model_(z=z, pos=pos)

charge
# Out:
# tensor([[-0.6355],
#         [ 0.2820],
#         [-0.2901],
#         [-0.1847],
#         [-0.2423],
#         [-0.1841],
#         [-0.2570],
#         [ 0.4666],
#         [ 0.2015],
#         [ 0.2091],
#         [ 0.2102],
#         [ 0.2096],
#         [ 0.2207]], grad_fn=<MulBackward0>)

# %%
'''Calculation of frequency, IR intensity, Raman activity for each vibration mode. (Units are consistent with Gaussian G16)'''
freq,iir,araman=vib_model(z=z, pos=pos)
for i in range(len(freq)):
    print('Vibration mode:{},Frequency:{:.8f},IR intensity:{:.8f},Raman activity:{:.8f}'
       .format(i+1,freq[i].item(),iir[i].item(),araman[i].item()))
# Out:
# Vibration mode:1,Frequency:234.93327332,IR intensity:60.03386688,Raman activity:0.68420947
# Vibration mode:2,Frequency:240.97122192,IR intensity:54.97782135,Raman activity:3.35585904
# Vibration mode:3,Frequency:389.43322754,IR intensity:0.05183639,Raman activity:0.02404462
# Vibration mode:4,Frequency:404.78494263,IR intensity:11.11936665,Raman activity:0.31459126
# Vibration mode:5,Frequency:489.18374634,IR intensity:0.88135123,Raman activity:0.09774461
# Vibration mode:6,Frequency:521.72967529,IR intensity:2.17806768,Raman activity:5.84700537
# Vibration mode:7,Frequency:613.24005127,IR intensity:5.68175220,Raman activity:0.09091432
# Vibration mode:8,Frequency:615.38946533,IR intensity:0.36473563,Raman activity:5.46547985
# Vibration mode:9,Frequency:758.73779297,IR intensity:92.44650269,Raman activity:0.05366505
# Vibration mode:10,Frequency:784.02587891,IR intensity:8.61821747,Raman activity:0.02411933
# Vibration mode:11,Frequency:803.38751221,IR intensity:22.74984550,Raman activity:17.50068283
# Vibration mode:12,Frequency:811.47271729,IR intensity:0.15838884,Raman activity:0.06103484
# Vibration mode:13,Frequency:851.58483887,IR intensity:0.09365693,Raman activity:0.01766521
# Vibration mode:14,Frequency:862.03979492,IR intensity:0.26837620,Raman activity:0.07469995
# Vibration mode:15,Frequency:985.88122559,IR intensity:3.52290320,Raman activity:30.17894745
# Vibration mode:16,Frequency:1009.12091064,IR intensity:3.03153920,Raman activity:9.62451458
# Vibration mode:17,Frequency:1046.92761230,IR intensity:23.07225418,Raman activity:0.71711051
# Vibration mode:18,Frequency:1140.75695801,IR intensity:37.33543777,Raman activity:4.72506618
# Vibration mode:19,Frequency:1146.94787598,IR intensity:123.50027466,Raman activity:3.73251128
# Vibration mode:20,Frequency:1154.11328125,IR intensity:1.60196018,Raman activity:2.94129682
# Vibration mode:21,Frequency:1233.63391113,IR intensity:77.02386475,Raman activity:10.21699142
# Vibration mode:22,Frequency:1295.32189941,IR intensity:11.93892097,Raman activity:0.93188447
# Vibration mode:23,Frequency:1332.42895508,IR intensity:20.04384804,Raman activity:0.22523358
# Vibration mode:24,Frequency:1451.45520020,IR intensity:23.60855484,Raman activity:0.39796814
# Vibration mode:25,Frequency:1477.11767578,IR intensity:55.99481964,Raman activity:0.91348547
# Vibration mode:26,Frequency:1579.03271484,IR intensity:28.91437531,Raman activity:8.67160416
# Vibration mode:27,Frequency:1595.42602539,IR intensity:51.13619995,Raman activity:14.33108139
# Vibration mode:28,Frequency:3043.97338867,IR intensity:16.79028320,Raman activity:73.94121552
# Vibration mode:29,Frequency:3066.66357422,IR intensity:0.09269213,Raman activity:75.01055908
# Vibration mode:30,Frequency:3072.03393555,IR intensity:15.31846523,Raman activity:77.45820618
# Vibration mode:31,Frequency:3082.52807617,IR intensity:14.31727791,Raman activity:51.90400696
# Vibration mode:32,Frequency:3090.39086914,IR intensity:3.10821700,Raman activity:276.48248291
# Vibration mode:33,Frequency:3679.24731445,IR intensity:55.52301407,Raman activity:113.82666779

# %%
'''Broadening of frequency and intensity'''
x_axis=torch.linspace(500, 4000, 3501)
yir=Lorenz_broadening(freq,iir,c=x_axis,sigma=15).detach().numpy()

yraman_act=Lorenz_broadening(freq,araman,c=x_axis,sigma=12)

#get raman intensity from raman act,frequency
yraman=get_raman_intensity(x_axis,yraman_act).detach().numpy()

x=x_axis.detach().numpy()

# %%
from matplotlib import pyplot as plt
# %matplotlib notebook
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import numpy as np
plt.rcParams['axes.unicode_minus'] = False  
plt.rcParams['xtick.direction'] = 'in'  # 
plt.rcParams['ytick.direction'] = 'in'

# %%
'''draw ir spectrum'''
plt.figure(figsize=(15,5))
plt.rc('font',family='Times New Roman', size=30)
plt.plot(x,yir/yir.max(),lw=2,label='IR',color='r')
plt.xlim(500,4000)
plt.tick_params(labelsize=30,width=3,length=10)
plt.show()
# Out:
# <div id='b857dac1-5db0-4711-bad2-49121c91a882'></div>

# %%
'''draw raman spectrum'''
plt.figure(figsize=(15,5))
plt.rc('font',family='Times New Roman', size=30)
plt.xlim(500,4000)
plt.plot(x,yraman/yraman.max(),lw=2,label='Raman',color='blue')
# Out:
# <div id='dd547e18-9339-4356-8da5-861e25985ac6'></div>

# %%
'''Calculate NMR Shift of C and H atom'''
sc,sh=nmr_model(pos=pos,z=z)

sc,sh
# Out:
# (tensor([[163.2916],
#          [117.0862],
#          [134.3739],
#          [124.6024],
#          [135.7667],
#          [120.1776]], grad_fn=<AddBackward0>),
#  tensor([[3.3317],
#          [6.6368],
#          [7.3450],
#          [6.9707],
#          [7.3930],
#          [7.1397]], grad_fn=<AddBackward0>))

# %%
# %matplotlib inline

# %%
'''Aggregation of hydrogen and carbon from the same chemical environment
in index,all hydrogen atoms and carbon atoms in the same chemical environment are represented by same number
    
'''
indexc=torch.LongTensor([0,1,2,3,2,1])
indexh=torch.LongTensor([0,1,2,3,2,1])
shiftc,intc,shifth,inth=nmr_sca(sc.reshape(-1),sh.reshape(-1),indexc,indexh)

# %%
'''Broadening of nmr shift and intensity'''
xh=torch.linspace(0, 12, 1201)
xc=torch.linspace(0,300,3001)
yc=Lorenz_broadening(shiftc,intc,c=xc,sigma=1).detach().numpy()
yh=Lorenz_broadening(shifth,inth,c=xh,sigma=0.05).detach().numpy()

# %%
'''draw nmrc spectrum'''
plt.figure(figsize=(15,5))
plt.xlim(0,200)
plt.plot(xc,yc/yc.max(),lw=2,label='NMRC13',color='black')
plt.show()

# %%
'''draw nmrh spectrum'''
plt.figure(figsize=(15,5))
plt.xlim(0,12)
plt.plot(xh,yh/yh.max(),lw=2,label='NMRH1',color='brown')
plt.show()

# %%
'''calculate uv spectrum'''
uv=uv_model_(z=z,pos=pos).detach().numpy()

# %%
'''draw uv spectrum'''
xuv=1239.85/torch.linspace(1.5,13.5,240).detach().numpy()
plt.figure(figsize=(15,5))
plt.rc('font',family='Times New Roman', size=30)
plt.xlim(100,300)
plt.plot(xuv,uv,lw=2,color='Violet')
